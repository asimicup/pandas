# %%
import pandas as pd

# %%
df = pd.read_csv('D:\Projects\car_price.csv')
df
# Out:
#      make_model      body_type Body Color     km  hp Gearing Type  \
# 0       Audi A1         Sedans      Black  56013  85    Automatic
# 1       Audi A1         Sedans        Red  80000  85    Automatic
# 2       Audi A1         Sedans      Black  83450  85    Automatic
# 3       Audi A1         Sedans      Brown  73000  85    Automatic
# 4       Audi A1         Sedans      Black  16200  85    Automatic
# ...         ...            ...        ...    ...  ..          ...
# 4795    Audi A3         Sedans      White     54  85       Manual
# 4796    Audi A3         Sedans      White     50  85       Manual
# 4797    Audi A3  Station wagon     Silver   6666  85       Manual
# 4798    Audi A3         Sedans     Silver     10  85       Manual
# 4799    Audi A3         Sedans     Silver     10  85       Manual
#
#                                                  Extras  price
# 0        Alloy wheels,Catalytic Converter,Voice Control  15770
# ...

# %%
df.columns
# Out:
# Index(['make_model', 'body_type', 'Body Color', 'km', 'hp', 'Gearing Type',
#        'Extras', 'price'],
#       dtype='object')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df = pd.read_csv('D:\Projects\car_price.csv', nrows= 2)
df
# Out:
#   make_model body_type Body Color     km  hp Gearing Type  \
# 0    Audi A1    Sedans      Black  56013  85    Automatic
# 1    Audi A1    Sedans        Red  80000  85    Automatic
#
#                                               Extras  price
# 0     Alloy wheels,Catalytic Converter,Voice Control  15770
# 1  Alloy wheels,Sport seats,Sport suspension,Voic...  14500

# %%
df = pd.read_csv('D:\Projects\car_price.csv', usecols = [3])
df
# Out:
#          km
# 0     56013
# 1     80000
# 2     83450
# 3     73000
# 4     16200
# ...     ...
# 4795     54
# 4796     50
# 4797   6666
# 4798     10
# 4799     10
#
# [4800 rows x 1 columns]

# %%
df = pd.read_csv('D:\Projects\car_price.csv', skiprows= 2)
df
# Out:
#       Audi A1         Sedans     Red  80000  85  Automatic  \
# 0     Audi A1         Sedans   Black  83450  85  Automatic
# 1     Audi A1         Sedans   Brown  73000  85  Automatic
# 2     Audi A1         Sedans   Black  16200  85  Automatic
# 3     Audi A1         Sedans   White  63668  85  Automatic
# 4     Audi A1  Station wagon   White  62111  85  Automatic
# ...       ...            ...     ...    ...  ..        ...
# 4793  Audi A3         Sedans   White     54  85     Manual
# 4794  Audi A3         Sedans   White     50  85     Manual
# 4795  Audi A3  Station wagon  Silver   6666  85     Manual
# 4796  Audi A3         Sedans  Silver     10  85     Manual
# 4797  Audi A3         Sedans  Silver     10  85     Manual
#
#      Alloy wheels,Sport seats,Sport suspension,Voice Control  14500
# 0                            Alloy wheels,Voice Control       14640
# 1                Alloy wheels,Sport seats,Voice Control       14500
# ...

# %%
df = pd.read_csv('D:\Projects\car_price.csv', skiprows= [2])
df
# Out:
#      make_model      body_type Body Color     km  hp Gearing Type  \
# 0       Audi A1         Sedans      Black  56013  85    Automatic
# 1       Audi A1         Sedans      Black  83450  85    Automatic
# 2       Audi A1         Sedans      Brown  73000  85    Automatic
# 3       Audi A1         Sedans      Black  16200  85    Automatic
# 4       Audi A1         Sedans      White  63668  85    Automatic
# ...         ...            ...        ...    ...  ..          ...
# 4794    Audi A3         Sedans      White     54  85       Manual
# 4795    Audi A3         Sedans      White     50  85       Manual
# 4796    Audi A3  Station wagon     Silver   6666  85       Manual
# 4797    Audi A3         Sedans     Silver     10  85       Manual
# 4798    Audi A3         Sedans     Silver     10  85       Manual
#
#                                                  Extras  price
# 0        Alloy wheels,Catalytic Converter,Voice Control  15770
# ...

# %%
df = pd.read_csv('D:\Projects\car_price.csv', skiprows= [3,4,5])
df
# Out:
#      make_model      body_type Body Color     km  hp Gearing Type  \
# 0       Audi A1         Sedans      Black  56013  85    Automatic
# 1       Audi A1         Sedans        Red  80000  85    Automatic
# 2       Audi A1         Sedans      White  63668  85    Automatic
# 3       Audi A1  Station wagon      White  62111  85    Automatic
# 4       Audi A1        Compact        Red  14986  85    Automatic
# ...         ...            ...        ...    ...  ..          ...
# 4792    Audi A3         Sedans      White     54  85       Manual
# 4793    Audi A3         Sedans      White     50  85       Manual
# 4794    Audi A3  Station wagon     Silver   6666  85       Manual
# 4795    Audi A3         Sedans     Silver     10  85       Manual
# 4796    Audi A3         Sedans     Silver     10  85       Manual
#
#                                                  Extras  price
# 0        Alloy wheels,Catalytic Converter,Voice Control  15770
# ...

# %%
df = pd.read_csv('D:\Projects\car_price.csv', index_col = 'make_model')
df
# Out:
#                 body_type Body Color     km  hp Gearing Type  \
# make_model
# Audi A1            Sedans      Black  56013  85    Automatic
# Audi A1            Sedans        Red  80000  85    Automatic
# Audi A1            Sedans      Black  83450  85    Automatic
# Audi A1            Sedans      Brown  73000  85    Automatic
# Audi A1            Sedans      Black  16200  85    Automatic
# ...                   ...        ...    ...  ..          ...
# Audi A3            Sedans      White     54  85       Manual
# Audi A3            Sedans      White     50  85       Manual
# Audi A3     Station wagon     Silver   6666  85       Manual
# Audi A3            Sedans     Silver     10  85       Manual
# Audi A3            Sedans     Silver     10  85       Manual
#
#                                                        Extras  price
# make_model
# Audi A1        Alloy wheels,Catalytic Converter,Voice Control  15770
# Audi A1     Alloy wheels,Sport seats,Sport suspension,Voic...  14500
# ...
