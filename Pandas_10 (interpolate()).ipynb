# %% [markdown]
# ### Interpolate function is used to fill the missing or NaN values in the dataframe or series
#
# It is a very powerfull function as compared to fillna() function
# It uses various interpolate function techniques

# %%
import pandas as pd

# %%
df = pd.read_csv('D:\Projects\CARS8Copy.csv')
df
# Out:
#      Invoice   Make                    Model   Type  Origin  EngineSize  \
# 0          0  Acura                      NaN    SUV    Asia         NaN
# 1          1  Acura           RSX Type S 2dr  Sedan    Asia         2.0
# 2          2  Acura                  TSX 4dr  Sedan    Asia         2.4
# 3          3    NaN                   TL 4dr  Sedan    Asia         3.2
# 4          4  Acura               3.5 RL 4dr  Sedan    Asia         3.5
# ..       ...    ...                      ...    ...     ...         ...
# 423      423  Volvo  C70 LPT convertible 2dr  Sedan  Europe         2.4
# 424      424  Volvo  C70 HPT convertible 2dr  Sedan  Europe         2.3
# 425      425  Volvo               S80 T6 4dr  Sedan  Europe         2.9
# 426      426  Volvo                      V40  Wagon  Europe         1.9
# 427      427  Volvo                     XC70  Wagon  Europe         2.5
#
#      Cylinders  Horsepower  Weight
# 0          6.0         265    4451
# ...

# %%
# it guesses the numeric values only
df.interpolate()
# Out:
#      Invoice   Make                    Model   Type  Origin  EngineSize  \
# 0          0  Acura                      NaN    SUV    Asia         NaN
# 1          1  Acura           RSX Type S 2dr  Sedan    Asia         2.0
# 2          2  Acura                  TSX 4dr  Sedan    Asia         2.4
# 3          3    NaN                   TL 4dr  Sedan    Asia         3.2
# 4          4  Acura               3.5 RL 4dr  Sedan    Asia         3.5
# ..       ...    ...                      ...    ...     ...         ...
# 423      423  Volvo  C70 LPT convertible 2dr  Sedan  Europe         2.4
# 424      424  Volvo  C70 HPT convertible 2dr  Sedan  Europe         2.3
# 425      425  Volvo               S80 T6 4dr  Sedan  Europe         2.9
# 426      426  Volvo                      V40  Wagon  Europe         1.9
# 427      427  Volvo                     XC70  Wagon  Europe         2.5
#
#      Cylinders  Horsepower  Weight
# 0          6.0         265    4451
# ...

# %%
df.interpolate(method = 'linear')
# Out:
#      Invoice   Make                    Model   Type  Origin  EngineSize  \
# 0          0  Acura                      NaN    SUV    Asia         NaN
# 1          1  Acura           RSX Type S 2dr  Sedan    Asia         2.0
# 2          2  Acura                  TSX 4dr  Sedan    Asia         2.4
# 3          3    NaN                   TL 4dr  Sedan    Asia         3.2
# 4          4  Acura               3.5 RL 4dr  Sedan    Asia         3.5
# ..       ...    ...                      ...    ...     ...         ...
# 423      423  Volvo  C70 LPT convertible 2dr  Sedan  Europe         2.4
# 424      424  Volvo  C70 HPT convertible 2dr  Sedan  Europe         2.3
# 425      425  Volvo               S80 T6 4dr  Sedan  Europe         2.9
# 426      426  Volvo                      V40  Wagon  Europe         1.9
# 427      427  Volvo                     XC70  Wagon  Europe         2.5
#
#      Cylinders  Horsepower  Weight
# 0          6.0         265    4451
# ...
