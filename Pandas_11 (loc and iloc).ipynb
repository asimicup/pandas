# %% [markdown]
# # Accessing the a group of rows and columns by labels or a boolean array
#
# we perform data selecting operatoins throug loc and iloc
#
# loc => accessing rows and columns using labels
# iloc => accessing rows and columns using their numbers (integer location based indexing)

# %%
import pandas as pd

# %%
df = pd.read_csv('D:\\Projects\\appledata.csv')
df
# Out:
#      Pixel count Circlarity  Length    WD  Ratio     CP  Radius    Pi  \
# 0           7.81        0.2     5.0   6.0  0.8:1  18.85     3.0  3.14
# 1           7.21        0.9     6.0   4.0  1.5:1  12.57     2.0  3.14
# 2           9.22        0.8     7.0   6.0  1.2:1  18.85     3.0  3.14
# 3          11.31          0     8.0   8.0    1:1  25.13     4.0  3.14
# 4          13.45        0.5     9.0  10.0  0.9:1  31.42     5.0  3.14
# ..           ...        ...     ...   ...    ...    ...     ...   ...
# 96         13.45        0.6     9.0  10.0  0.9:1  31.42     5.0  3.14
# 97         10.00        0.5     8.0   6.0  1.3:1  18.85     3.0  3.14
# 98          9.43        0.4     5.0   8.0  0.6:1  25.13     4.0  3.14
# 99         11.66        0.3     6.0  10.0  0.6:1  31.42     5.0  3.14
# 100          NaN        NaN     NaN   NaN    NaN    NaN     NaN   NaN
#
#      total Area   Center Point   Fruit
# 0          28.27            3.0    1.0
# 1          12.57            2.0    0.0
# ...

# %%
df.loc[0]
# Out:
# Pixel count       7.81
# Circlarity         0.2
# Length             5.0
# WD                 6.0
# Ratio            0.8:1
# CP               18.85
# Radius             3.0
# Pi                3.14
# total Area       28.27
# Center Point       3.0
# Fruit              1.0
# Name: 0, dtype: object

# %%
df.loc[[0,1]]
# Out:
#    Pixel count Circlarity  Length   WD  Ratio     CP  Radius    Pi  \
# 0         7.81        0.2     5.0  6.0  0.8:1  18.85     3.0  3.14
# 1         7.21        0.9     6.0  4.0  1.5:1  12.57     2.0  3.14
#
#    total Area   Center Point   Fruit
# 0        28.27            3.0    1.0
# 1        12.57            2.0    0.0

# %%
df.loc[4, 'Length']
# Out:
# 9.0

# %%
df.loc[0:3, 'Pixel count']
# Out:
# 0     7.81
# 1     7.21
# 2     9.22
# 3    11.31
# Name: Pixel count, dtype: float64

# %%
df.loc[df['Fruit'] < 1]
# Out:
#     Pixel count Circlarity  Length    WD  Ratio     CP  Radius    Pi  \
# 1          7.21        0.9     6.0   4.0  1.5:1  12.57     2.0  3.14
# 3         11.31          0     8.0   8.0    1:1  25.13     4.0  3.14
# 5         12.81        0.3    10.0   8.0  1.3:1  25.13     4.0  3.14
# 11         8.94        0.4     8.0   4.0    2:1  12.57     2.0  3.14
# 12        10.82        0.7     9.0   6.0  1.5:1  18.85     3.0  3.14
# 13        13.60        0.8    11.0   8.0  1.4:1  25.13     4.0  3.14
# 14        15.62        0.5    12.0  10.0  1.2:1  31.42     5.0  3.14
# 15        11.66        0.9    10.0   6.0  1.7:1  18.85     3.0  3.14
# 16        12.53        0.8    11.0   6.0  1.8:1  18.85     3.0  3.14
# 17        14.14        0.7    10.0  10.0    1:1  31.42     5.0  3.14
# 20         9.85        0.3     9.0   4.0  2.3:1  12.57     2.0  3.14
# 24         9.22        0.8     7.0   6.0  1.2:1  18.85     3.0  3.14
# 25         8.94        0.3     8.0   4.0    2:1  12.57     2.0  3.14
# ...

# %%
df.iloc[0]
# Out:
# Pixel count       7.81
# Circlarity         0.2
# Length             5.0
# WD                 6.0
# Ratio            0.8:1
# CP               18.85
# Radius             3.0
# Pi                3.14
# total Area       28.27
# Center Point       3.0
# Fruit              1.0
# Name: 0, dtype: object

# %%
df.iloc[[0]]
# Out:
#    Pixel count Circlarity  Length   WD  Ratio     CP  Radius    Pi  \
# 0         7.81        0.2     5.0  6.0  0.8:1  18.85     3.0  3.14
#
#    total Area   Center Point   Fruit
# 0        28.27            3.0    1.0

# %%
df.iloc[:, 0]
# Out:
# 0       7.81
# 1       7.21
# 2       9.22
# 3      11.31
# 4      13.45
#        ...
# 96     13.45
# 97     10.00
# 98      9.43
# 99     11.66
# 100      NaN
# Name: Pixel count, Length: 101, dtype: float64

# %%
df.iloc[[0,1]]
# Out:
#    Pixel count Circlarity  Length   WD  Ratio     CP  Radius    Pi  \
# 0         7.81        0.2     5.0  6.0  0.8:1  18.85     3.0  3.14
# 1         7.21        0.9     6.0  4.0  1.5:1  12.57     2.0  3.14
#
#    total Area   Center Point   Fruit
# 0        28.27            3.0    1.0
# 1        12.57            2.0    0.0
